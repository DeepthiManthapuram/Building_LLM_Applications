# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiManthapuram/Building_LLM_Applications/blob/main/Introduction_to_langchain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INSTALLING MODEL
#
# !pip install -U langchain-[provider_name]

# %%
# !pip install -U langchain-google-genai

# %% [markdown]
# CONFIGURE GEMINI AI MODEL

# %%
from google.colab import userdata

from langchain.chat_models import init_chat_model

from langchain.messages import HumanMessage, SystemMessage

# %%
api_key = userdata.get('GEMINI_API_KEY')

# %%
system_msg = SystemMessage("You are helpful assistant.")
human_msg = HumanMessage("what is RAG?")
messages = [system_msg, human_msg]

# %% [markdown]
# INITIALISING CHAT MODEL
#
#
# model = init_chat_model(
#     "[provider_name]: [model_name]",
#     api_key = [api_key]
# )

# %%
model = init_chat_model(
    "google_genai:gemini-3.5-flash",
    api_key = api_key
)

#The object of the model is stored in "model".

# %%
response = model.invoke(messages)

# %%
print(response)
# Out:
# content=[{'type': 'text', 'text': '**RAG** stands for **Retrieval-Augmented Generation**. \n\nIt is a technique used in Artificial Intelligence (specifically with Large Language Models, or LLMs, like ChatGPT) to make AI responses more accurate, up-to-date, and relevant by anchoring them to external sources of information.\n\nTo understand RAG, it helps to use a simple analogy:\n\n### The Analogy: Closed-Book vs. Open-Book Exam\n* **Standard LLM (Without RAG) is like taking a "closed-book" exam.** The AI relies purely on what it memorized during its training. If you ask it about something that happened after its training cut-off date, or about your private company files, it won\'t know the answer and might hallucinate (make things up).\n* **LLM with RAG is like taking an "open-book" exam.** Before answering your question, the AI is allowed to search a library of documents (like PDFs, websites, or databases), find the relevant pages, read them, and then write a highly accurate answer b
# ...

# %%
print(response.content)
# Out:
# [{'type': 'text', 'text': '**RAG** stands for **Retrieval-Augmented Generation**. \n\nIt is a technique used in Artificial Intelligence (specifically with Large Language Models, or LLMs, like ChatGPT) to make AI responses more accurate, up-to-date, and relevant by anchoring them to external sources of information.\n\nTo understand RAG, it helps to use a simple analogy:\n\n### The Analogy: Closed-Book vs. Open-Book Exam\n* **Standard LLM (Without RAG) is like taking a "closed-book" exam.** The AI relies purely on what it memorized during its training. If you ask it about something that happened after its training cut-off date, or about your private company files, it won\'t know the answer and might hallucinate (make things up).\n* **LLM with RAG is like taking an "open-book" exam.** Before answering your question, the AI is allowed to search a library of documents (like PDFs, websites, or databases), find the relevant pages, read them, and then write a highly accurate answer based on 
# ...
