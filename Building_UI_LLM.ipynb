# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepthiManthapuram/Building_LLM_Applications/blob/main/Building_UI_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %% [markdown]
# INSTALL GRADIO FOR BUILDING UI

# %%
# !pip install -q gradio

# %% [markdown]
# IMPORT NECESSARY MODULES

# %%
from google import genai
from google.genai import types
from google.colab import userdata
import gradio as gr

# %%
client = genai.Client(api_key = userdata.get("GEMINI_API_KEY"))
client

# %%
personalities = {
    "Friendly": """
    You are a friendly and encouraging assistant.
    Use simple language, a warm tone, and make the content easy to understand.
    Keep explanations engaging and approachable.
    """,

    "Academic": """
    You are an academic and professional assistant.
    Use precise language, formal tone, and well-structured explanations.
    Focus on accuracy, clarity, and educational value.
    """
  }

def study_assistant(question, persona):

  response = client.models.generate_content(
      model = 'gemini-3.5-flash',
      config = types.GenerateContentConfig(
          system_instruction = personalities[persona],
          temperature = 0.4,
          max_output_tokens = 1000
      ),
      contents = question
  )
  return response.text

# %%
demo = gr.Interface(
    fn = study_assistant,
    inputs = [gr.Textbox(label = "Question", lines = 4, placeholder = "Ask a question..."),
        gr.Dropdown(choices = list(personalities.keys()), value = "Friendly", label = "Personality")],
    outputs = gr.Textbox(label = "Explanation", lines = 10),
    title = "Study Assistant",
    description = "Ask a question to get simple Explanation from AI."
)

demo.launch(debug = True)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://97e87a7b0614fcf395.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://97e87a7b0614fcf395.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
output = study_assistant("Explain LLM architecture")
print(output)
